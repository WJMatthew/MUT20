# %% [markdown]
# ## MUT20 Player Scraper Usage Example
# - Date is only used to track scrape date, url is the first page of the pages you want to scrape on Muthead.
#
# TODO:
# - Finish mapping archetype ids (int) to actual archetype name and implement
# - Forgot ZCV, fixed code but need to re-scrape.

# %%
from MUTScraper20 import Player, PlayerHandler, JSONParser
import pandas as pd
# %load_ext autoreload
# %autoreload 2


# Not implemented yet
# Hester - 47: Unkown, Dante Hall 
archetype_map = {4: 'Field General (QB)', 16: 'Improvisor (QB)', 40: 'Scrambler (QB)', 45: 'Strong Arm (QB)',
                 5: 'Physical (WR)', 8: 'Route Running (WR)', 10: 'Deep Threat (WR)', 36: 'Slot (WR)',
                 47: 'Unknown',
                 26: 'Elusive Back (HB)', 30: 'Powerback (HB)', 33: 'Receiving Back (HB)',
                 15: 'Power (OT)', 7: 'Pass Protector (OT)',
                 11: 'Power (OG)', 19: 'Pass Protector (OG)', 46: 'Agile (OG)',
                 18: 'Power (C)', 38: 'Agile (C)', 39: 'Pass Protector (C)',
                 3: 'Vertical Threat (TE)', 14: 'Blocking (TE)', 44: 'Possession (TE)',
                 }

def get_archtype(arch_id):
    if arch_id in archetype_map.keys():
        return archetype_map[arch_id]
    else:
        return 'N/A'

def parse_json(date):
    jp = JSONParser(date=date)
    jp.load_json()
    jp.parse_json_items()
    jp.jsons_to_dataframe()
    jp.save_to_csv()
    return jp


# Start here by inputting date and link
date = '08-01-2020'
url = 'https://www.muthead.com/20/players/?overall__gte=91'

ph = PlayerHandler(date=date, url=url)
ph.handle_players()
jp = parse_json(date)
# Out:
# Number of pages: 23
# https://www.muthead.com/20/players/?overall__gte=91
# 443 player links gathered.
# Filtering player list, before: 443
# Completed filtering, after: 54

# %% [markdown]
# ## Viewing our data

# %%
import os
import pandas as pd


directory = 'data'
drop_duplicates = False
index_issue = False
save = False

dfs = {}

for file in os.listdir(directory):
    if '.csv' in file:

        print(directory, file)
        df = pd.read_csv(os.path.join(directory, file))
        
        if index_issue:
            # shouldn't need, index problem 
            df = df[df.columns.difference(['Unnamed: 0'])]
        
        # dropping duplicates because of previous error
        if drop_duplicates:
            df = df.drop_duplicates(subset=df.columns.difference(['date_scraped']))
        
        if save:
            df.to_csv(os.path.join(directory, file), index=False)
            
        dfs[file.split('.csv')[0]] = df
# Out:
# data DEF.csv
# data OFF.csv
# data QB.csv
# data ST.csv

# %%
_ = [print(k, v.shape) for k,v in dfs.items()]
# Out:
# OFF (413, 69)
# QB (64, 75)
# DEF (308, 69)
# ST (13, 64)

# %%
def filter_df(df, positions, sort_by=None):
    if type(positions) != list: 
        positions = [positions]
    result = df[ df['position'].isin(positions)]
    if sort_by:
        return result.sort_values(sort_by, ascending=False)
    return result

#dfs['QB'].sort_values('OVR', ascending=False).head(10)

#filter_df(dfs['OFF'], 'HB', 'BTK')[['name', 'BTK', 'SPD', 'TRK', 'AGI']]
oline = filter_df(dfs['OFF'], ['LT', 'LG', 'C', 'RG', 'LT', 'RT','TE'])#, 'TAK')[['name', 'TAK', 'POW', 'SPD', 'HT']]
rbs = filter_df(dfs['OFF'], ['HB', 'FB'])
wrs = filter_df(dfs['OFF'], ['WR'])

# %%
oline['archetype'] = oline['archetype_id'].apply(get_archtype)

oline[['name', 'position', 'program', 'OVR', 'RBK', 'PBK', 'PBF', 'PBP', 'SPD', 'IMP', 'LBK', 'STR', 
       'AGI', 'AWR', 'WT', 'HT', 'archetype']].to_csv('data/oline_jan8.csv')

# %%
oline[ (oline['WT'] >= 300) & (oline['RBK'] >= 88)].sort_values('RBK', ascending=False) \
    [['name', 'position', 'program', 'OVR','RBK', 'SPD', 'IMP', 'LBK', 'PBF', 'STR', 'AGI', 'AWR', 'WT']].reset_index(drop=True).head(15)
# Out:
#                   name position                  program  OVR  RBK  SPD  IMP  \
# 0          Larry Allen       RG                  NFL 100   94   94   66   93
# 1   Rodger Saffold III       LG         Ultimate Kickoff   91   93   59   93
# 2       Ronnie Stanley       LT             NFL Playoffs   95   93   67   92
# 3     Travis Frederick        C              Most Feared   92   92   51   91
# 4       Bruce Matthews       LG                  NFL 100   94   92   70   92
# 5            Alex Mack        C             Heavyweights   91   92   60   93
# 6         Jordan Gross       LT                  Legends   94   91   68   86
# 7            Matt Birk        C             Series Redux   94   91   68   86
# 8            Matt Birk        C                  Legends   94   91   68   86
# 9        Marshal Yanda       RG              Gauntlet II   92   91   60   90
# 10          Joe Thomas       LT  Madden Ultimate Team 10   93   90   70   90
# 11     Brandon Scherff       RG             Heavyweights   90   90   68   89
# 12          Joe Thomas       LT             Series Redux   93   90   70   90
# 13      David DeCastro       RG               MUT Heroes   91   90   55   86
# 14          Erik McCoy        C             NFL Playoffs   91   90   74   95
#
#     LBK  PBF  STR  AGI  AWR   WT
# 0    89   90   95   62   89  335
# 1    87   81   84   66   96  325
# 2    94   95   88   76   97  320
# 3    89   83   89   62   94  318
# 4    92   92   91   71   93  305
# 5    92   81   89   66   95  311
# 6    86   94   92   67   93  305
# 7    87   90   91   68   93  310
# 8    87   90   91   68   93  310
# 9    80   88   91   64   93  305
# 10   90   93   88   72   90  312
# 11   92   82   89   70   86  319
# 12   90   93   88   72   90  312
# 13   88   89   90   67   87  316
# 14   93   89   87   59   90  315

# %%
rbs['archetype'] = rbs['archetype_id'].apply(get_archtype)

rbs[['name', 'position', 'program', 'OVR', 'SPD', 'AGI', 'ACC', 'BTK', 'TRK', 'ELU', 'JKM', 'SFA', 'CTH', 'CAR', 
     'HT', 'WT', 'PBK', 'archetype', 'trait_clutch', 'trait_fights_for_extra_yards', 'trait_drops_open_passes']].reset_index(drop=True).head(15)
# Out:
#                    name position           program  OVR  SPD  AGI  ACC  BTK  \
# 0       Adrian Peterson       HB        Zero Chill   91   90   89   90   89
# 1         Walter Payton       HB        Zero Chill   95   93   94   93   95
# 2   Christian McCaffrey       HB        Zero Chill   94   91   96   92   84
# 3       Kordell Stewart       HB   Out of Position   95   92   93   94   90
# 4           LeVeon Bell       HB      Series Redux   93   87   93   90   90
# 5           Tarik Cohen       HB       Most Feared   90   88   93   89   85
# 6        Clinton Portis       HB           Legends   90   85   85   86   87
# 7        Mark Ingram II       HB      Series Redux   91   86   85   89   90
# 8           LeVeon Bell       HB       Most Feared   93   87   93   90   90
# 9           Dalvin Cook       HB             Blitz   92   90   93   91   90
# 10          Gale Sayers       HB           Legends   91   90   90   90   89
# 11        Tevin Coleman       HB      Series Redux   92   92   91   90   80
# 12      Ezekiel Elliott       HB  Signature Series   92   87   92   88   90
# 13         Chris Carson       HB  Ultimate Kickoff   93   87   82   88   93
# 14            Jim Brown       HB           Legends   91   89   86   88   90
#
#     TRK  ELU           ...            SFA  CTH  CAR  HT   WT  PBK  \
# 0    88   84           ...             90   60   86  73  220   44
# 1    92   91           ...             93   75   91  70  200   66
# 2    54   91           ...             75   84   88  71  202   56
# 3    71   94           ...             78   79   92  73  218   28
# 4    89   86           ...             91   75   87  73  225   61
# 5    61   92           ...             59   73   77  66  179   45
# 6    78   89           ...             83   65   87  71  218   61
# 7    91   76           ...             85   67   90  69  215   60
# 8    89   86           ...             91   75   87  73  225   61
# 9    75   88           ...             81   66   88  70  210   63
# 10   75   90           ...             78   67   83  72  198   51
# 11   81   86           ...             79   67   89  73  210   55
# 12   83   85           ...             89   70   85  72  225   52
# 13   89   78           ...             92   62   92  71  222   54
# 14   87   81           ...             89   64   89  74  232   63
#
#               archetype trait_clutch trait_fights_for_extra_yards  \
# 0        Powerback (HB)        False                         True
# 1     Elusive Back (HB)         True                         True
# 2   Receiving Back (HB)         True                         True
# 3     Elusive Back (HB)        False                         True
# 4     Elusive Back (HB)         True                         True
# 5     Elusive Back (HB)        False                        False
# 6     Elusive Back (HB)        False                         True
# 7        Powerback (HB)         True                         True
# 8     Elusive Back (HB)         True                         True
# 9     Elusive Back (HB)        False                         True
# 10    Elusive Back (HB)         True                         True
# 11    Elusive Back (HB)        False                        False
# 12    Elusive Back (HB)         True                         True
# 13       Powerback (HB)        False                         True
# 14       Powerback (HB)        False                         True
#
#    trait_drops_open_passes
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# 5                    False
# 6                    False
# 7                    False
# 8                    False
# 9                    False
# 10                   False
# 11                   False
# 12                   False
# 13                   False
# 14                   False
#
# [15 rows x 21 columns]

# %%
rbs[['name', 'position', 'program', 'OVR', 'SPD', 'AGI', 'ACC', 'BTK', 'TRK', 'ELU', 'JKM', 'SPM', 'SFA', 'CTH', 'CIT', 'CAR', 
     'HT', 'WT', 'PBK', 'archetype', 'trait_clutch', 'trait_fights_for_extra_yards', 'trait_drops_open_passes'
    ]].reset_index(drop=True).to_csv('data/rbs_jan8.csv')

# %%
# from: https://twitter.com/MUT_Leaks20/status/1156002794869911552
(x1, y1), (x2, y2) = (150, 0), (290, 0.8)
m1 = (y2-y1)/(x2-x1)
b1 = -m1 * 150

(x3, y3) = (350, 1.0)

def get_weight_contribution_rbk(weight):
    if weight <= 150: return 0
    elif weight <= 290: return m1*weight + b1
    return (1/300)*weight - (1/6)

def calc_run_block(rbk, weight, strength, vec=True):
    if vec:
        return (0.6 * rbk) + (0.175 * weight.apply(lambda x: get_weight_contribution_rbk(x))) + (0.225 * strength)
    else:
        return (0.6 * rbk) + (0.175 * get_weight_contribution_rbk(weight)) + (0.225 * strength)

# %%
#calc_run_block(79, 288, 94, False)

oline['RBK_calc'] = calc_run_block(oline['RBK'],oline['WT'], oline['STR'])

#tes = oline[ oline['position'] == 'TE']
#tes.sort_values('RBK_calc', ascending=False)

stat_cols = ['RBK', 'IMP', 'LBK', 'SPD', 'AGI']
oline['pulling_guard'] = oline[stat_cols].mean(axis=1)
oline.sort_values('pulling_guard', ascending=False)[['name', 'program', 'position', 'pulling_guard'] + stat_cols].head(15)
oline['all_around_guard'] = oline[['RBK_calc', 'PBF', 'PBP', 'pulling_guard']].mean(1)
oline.sort_values('all_around_guard', ascending=False)[['name', 'program', 'position', 'all_around_guard'] + stat_cols + ['PBF', 'PBP']].head(15)
oline[ oline['position'] == 'TE'].sort_values('RBK_calc', ascending=False)[['name', 'program', 'position', 'RBK_calc', 'RBK', 'WT', 'STR', 'HT', 'SPD', 'CTH', 'CIT', 'SPC', 'SRR', 'MRR']].reset_index(drop=True)
# Out:
#               name                   program position  RBK_calc  RBK   WT  \
# 0   Marcedes Lewis                Flashbacks       TE    70.542   87  267
# 1        J.J. Watt           Out of Position       TE    68.688   79  288
# 2    George Kittle              Series Redux       TE    67.822   84  247
# 3    George Kittle                MUT Heroes       TE    67.822   84  247
# 4   Delanie Walker                MUT Heroes       TE    67.598   84  248
# 5   Rob Gronkowski                Zero Chill       TE    67.090   79  265
# 6     Jason Witten                MUT Heroes       TE    64.688   78  263
# 7     Hunter Henry          Team of the Week       TE    64.075   80  250
# 8   Delanie Walker            Theme Builders       TE    64.073   80  248
# 9   Rob Gronkowski              Series Redux       TE    64.015   75  265
# 10  Rob Gronkowski   Madden Ultimate Team 10       TE    64.015   75  265
# 11   George Kittle            Theme Builders       TE    63.922   79  247
# 12   Austin Hooper        Football Outsiders       TE    62.873   78  248
# 13     Dave Casper                   Legends       TE    61.890   73  240
# 14    Mark Andrews              Series Redux       TE    61.678   73  253
# 15    Mark Andrews                     Blitz       TE    61.678   73  253
# 16  Shannon Sharpe                   Legends       TE    61.503   72  228
# 17     David Njoku          Ultimate Kickoff       TE    60.846   75  246
# 18  T.J. Hockenson           Rookie Premiere       TE    60.776   73  251
# 19  T.J. Hockenson                   Harvest       TE    60.776   73  251
# 20  Shannon Sharpe                   Legends       TE    60.603   72  228
# 21     O.J. Howard              Series Redux       TE    60.550   73  250
# 22     O.J. Howard          Signature Series       TE    60.550   73  250
# 23     Dave Casper                   Legends       TE    60.390   72  240
# 24   Darren Waller                     Blitz       TE    60.180   75  255
# 25   Darren Waller              Series Redux       TE    60.180   75  255
# 26     Taysom Hill           Out of Position       TE    60.146   72  221
# 27  Shannon Sharpe                   Legends       TE    59.178   70  228
# 28    Darren Fells          Team of the Week       TE    58.620   69  270
# 29     O.J. Howard          Ultimate Kickoff       TE    58.525   70  250
# ..             ...                       ...      ...       ...  ...  ...
# 32   Darren Waller        Football Outsiders       TE    57.705   72  255
# 33     Dave Casper                   Legends       TE    57.315   68  240
# 34    Travis Kelce          Signature Series       TE    57.185   67  260
# 35    Travis Kelce              Series Redux       TE    57.185   67  260
# 36     Dave Casper                   Legends       TE    56.940   67  240
# 37    Vernon Davis                  Veterans       TE    56.569   66  244
# 38   Tony Gonzalez                   NFL 100       TE    56.343   66  243
# 39     Dave Casper                   Legends       TE    55.890   66  240
# 40     Dave Casper            Theme Diamonds       TE    55.290   65  240
# 41     Evan Engram          Signature Series       TE    55.290   68  240
# 42     Evan Engram              Series Redux       TE    55.290   68  240
# 43    Travis Kelce            Core Set Elite       TE    54.485   64  260
# 44    Jimmy Graham                  Veterans       TE    54.040   64  265
# 45       Zach Ertz                   Harvest       TE    53.875   63  250
# 46     Jordan Reed                Zero Chill       TE    53.121   64  246
# 47      Jared Cook               Gauntlet II       TE    53.054   62  254
# 48      Eric Ebron                Flashbacks       TE    52.828   62  253
# 49       Noah Fant          Team of the Week       TE    52.224   61  249
# 50    Kyle Rudolph          Team of the Week       TE    52.090   60  265
# 51      Greg Olsen                MUT Heroes       TE    52.005   61  255
# 52  Kellen Winslow              Series Redux       TE    51.551   61  251
# 53  Kellen Winslow                   Legends       TE    51.551   61  251
# 54       Zach Ertz        MUT20 Launch Promo       TE    51.400   60  250
# 55      Jared Cook                  Veterans       TE    49.154   57  254
# 56    Dallas Clark                   Legends       TE    49.002   56  252
# 57      Greg Olsen  Ultimate Trainers 85 OVR       TE    47.280   55  255
# 58    Dallas Clark                   Legends       TE    46.902   54  252
# 59    Dallas Clark                   Legends       TE    45.477   52  252
# 60    Dallas Clark                   Legends       TE    44.427   51  252
# 61    Dallas Clark                   Legends       TE    44.052   50  252
#
#     STR  HT  SPD  CTH  CIT  SPC  SRR  MRR
# 0    81  78   74   84   79   80   76   70
# 1    94  77   83   90   87   85   85   78
# 2    77  76   85   91   83   86   84   82
# 3    77  76   85   91   83   86   84   82
# 4    76  74   82   86   84   77   81   78
# 5    87  78   86   93   94   93   87   84
# 6    79  78   74   92   90   87   80   77
# 7    71  77   80   82   80   82   75   72
# 8    71  74   77   82   79   73   77   73
# 9    84  78   83   89   90   90   84   81
# 10   84  78   83   89   90   90   84   81
# 11   73  76   81   85   77   80   78   76
# 12   71  76   80   91   85   82   78   75
# 13   80  76   85   90   92   90   85   86
# 14   79  77   85   88   85   84   83   83
# 15   79  77   85   88   85   84   83   83
# 16   81  74   84   87   90   84   85   85
# 17   70  76   83   81   84   86   81   79
# 18   75  77   81   91   90   90   85   81
# 19   75  77   81   91   90   90   85   81
# 20   77  74   79   85   84   82   84   84
# 21   74  78   86   91   87   87   86   81
# 22   74  78   86   91   87   87   86   81
# 23   76  76   80   88   90   88   83   84
# 24   67  78   89   90   91   94   80   74
# 25   67  78   89   90   91   94   80   74
# 26   75  74   90   89   88   82   83   75
# 27   76  74   80   82   82   80   82   81
# 28   76  79   72   88   83   84   79   72
# 29   73  78   85   89   85   85   82   78
# ..  ...  ..  ...  ...  ...  ...  ...  ...
# 32   64  78   86   86   87   91   72   66
# 33   73  76   78   84   86   84   79   80
# 34   75  77   81   88   88   88   84   82
# 35   75  77   81   88   88   88   84   82
# 36   74  76   77   83   85   83   78   80
# 37   75  75   84   88   84   84   83   80
# 38   74  77   87   94   93   92   92   91
# 39   72  76   79   82   84   82   77   79
# 40   72  76   77   83   85   83   79   79
# 41   64  75   88   86   80   90   84   82
# 42   64  75   88   86   80   90   84   82
# 43   71  77   77   84   84   84   80   78
# 44   69  79   78   92   85   90   80   77
# 45   71  77   81   94   91   90   92   89
# 46   65  74   83   92   86   87   85   82
# 47   70  77   84   92   87   89   86   84
# 48   69  76   83   87   87   89   80   78
# 49   69  76   86   86   82   85   79   75
# 50   71  78   73   92   84   87   80   76
# 51   68  77   82   93   93   92   86   83
# 52   66  77   82   90   89   90   91   85
# 53   66  77   82   90   89   90   91   85
# 54   68  77   78   91   88   87   89   86
# 55   66  77   80   86   81   83   79   77
# 56   68  75   84   92   92   89   89   90
# 57   63  77   77   87   87   86   80   77
# 58   64  75   79   91   91   88   89   89
# 59   63  75   80   88   88   85   86   86
# 60   61  75   77   86   86   83   84   85
# 61   62  75   76   85   85   82   83   84
#
# [62 rows x 14 columns]

# %%
dfs['DEF'].columns
# Out:
# Index(['ACC', 'AGI', 'AWR', 'BCV', 'BKS', 'BSK', 'BTK', 'CAR', 'CIT', 'CTH',
#        'DRR', 'ELU', 'FNM', 'HT', 'IMP', 'JKM', 'JMP', 'KR', 'LBK', 'MCV',
#        'MRR', 'OVR', 'PBF', 'PBK', 'PBP', 'POW', 'PRC', 'PRS', 'PUR', 'PWM',
#        'RBF', 'RBK', 'RBP', 'RLS', 'SFA', 'SPC', 'SPD', 'SPM', 'SRR', 'STA',
#        'STR', 'TAK', 'TGH', 'TRK', 'WT', 'archetype_id', 'date_scraped',
#        'has_power_up', 'image', 'jersey_number', 'last_name', 'name',
#        'player_id', 'position', 'program', 'quicksell_amount', 'release_date',
#        'salary_cap_cost', 'team', 'trait_big_hitter', 'trait_clutch',
#        'trait_high_motor', 'trait_lb_style', 'trait_penalty',
#        'trait_plays_ball_in_the_air', 'trait_strips_ball',
#        'trait_utilizes_bull_rush_moves', 'trait_utilizes_spin_moves',
#        'trait_utilizes_swim_moves'],
#       dtype='object')
